# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

X, y = make_classification(
    n_features=10,
    n_samples=1000,
    n_informative=8,
    n_redundant=2,
    n_repeated=0,
    n_classes=2,
    random_state=42,
)

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(
    DecisionTreeClassifier(),
    {"criterion": ["gini", "entropy"], "max_depth": [5, 10, 15, 20]},
    cv=5,
    return_train_score=False,
)
clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.005407      0.001026         0.001201        0.000749
# 1       0.007010      0.000884         0.000910        0.000501
# 2       0.007807      0.000753         0.000601        0.000491
# 3       0.009236      0.001524         0.000600        0.000490
# 4       0.006800      0.000749         0.000800        0.000400
# 5       0.009718      0.000847         0.000809        0.000405
# 6       0.013196      0.001935         0.000922        0.000516
# 7       0.010719      0.000391         0.000599        0.000489
#
#   param_criterion  param_max_depth                                     params  \
# 0            gini                5      {'criterion': 'gini', 'max_depth': 5}
# 1            gini               10     {'criterion': 'gini', 'max_depth': 10}
# 2            gini               15     {'criterion': 'gini', 'max_depth': 15}
# 3            gini               20     {'criterion': 'gini', 'max_depth': 20}
# 4         entropy                5   {'criterion': 'entropy', 'max_depth': 5}
# 5         entropy               10  {'criterion': 'entropy', 'max_depth': 10}
# 6         entropy               15  {'criterion': 'entropy', 'max_depth': 15}
# 7         entropy               20  {'criterion': 'entropy', 'max_depth': 20}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.780              0.795              0.740              0.795
# 1              0.800              0.745              0.820              0.785
# 2              0.800              0.750              0.805              0.810
# 3              0.795              0.745              0.800              0.805
# 4              0.765              0.780              0.755              0.815
# 5              0.780              0.800              0.815              0.770
# 6              0.770              0.795              0.845              0.805
# 7              0.760              0.795              0.845              0.805
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.770            0.776        0.020347                8
# 1              0.815            0.793        0.026944                5
# 2              0.815            0.796        0.023537                3
# 3              0.825            0.794        0.026533                4
# 4              0.775            0.778        0.020396                7
# 5              0.785            0.790        0.015811                6
# 6              0.855            0.814        0.031686                1
# 7              0.850            0.811        0.033377                2

# %%
from sklearn.model_selection import RandomizedSearchCV

clf = RandomizedSearchCV(
    DecisionTreeClassifier(),
    {"criterion": ["gini", "entropy"], "max_depth": [5, 10, 15, 20]},
    cv=5,
    return_train_score=False,
    n_iter=3,
)
clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.014182      0.001358         0.001367        0.000925
# 1       0.007478      0.000735         0.000902        0.000493
# 2       0.005120      0.000492         0.000509        0.000448
#
#    param_max_depth param_criterion                                     params  \
# 0               20         entropy  {'max_depth': 20, 'criterion': 'entropy'}
# 1               20            gini     {'max_depth': 20, 'criterion': 'gini'}
# 2                5            gini      {'max_depth': 5, 'criterion': 'gini'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.765              0.810              0.845               0.80
# 1              0.810              0.760              0.810               0.80
# 2              0.780              0.795              0.755               0.79
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0               0.86            0.816        0.033675                1
# 1               0.82            0.800        0.020976                2
# 2               0.77            0.778        0.014353                3
